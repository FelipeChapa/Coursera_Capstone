# %% [markdown]
#  <img src="https://yardnyc.com/wp-content/uploads/2018/09/YARD_SITE_2018_NEWS_HERO_FORBES_092318.jpg" alt="New York Landscape" style="width:600px;height:300px;">

# %% [markdown]
# # Purchase recommendation for real estate in New York
# ### Where should you purchase your next house in New York? Unsupervised clustering and statistical regression analysis.

# %% [markdown]
# ### Table of contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1.  <a href="#Introduction">1.1 Introduction</a>
#
# 2.  <a href="#ETL">2.1 Data ETL Process</a>
#
# 3.  <a href="#item3"></a>
#
# 4.  <a href="#item4"></a>
#
# 5.  <a href="#item5"></a>
#     </font>
#     </div>

# %% [markdown]
# ### <a id="Introduction"> </a> 1.1 Introduction
# Considering the various expensive house prices in the different neighborhood and boroughs of New York, a careful analysis of current house prices as well as future house market house price prediction are important for consideration when deciding on which house to buy. For this scenario, we will assume the investor is interested in buying residential homes in New York. Specifically, I am interested in analyzing the price of houses in heach neighborhood, amount of houses bought/sold, location analysis, an unsupervised clustering analysis, as well as a regression in order to predict future house value for the prospective neighborhoods.
# Machine learning tools such as unsupervised clustering and statistical regression are used in order to identify common neighborhoods and analyze curent and future property prices.

# %% [markdown]
# ### 1.2 Selection of datasets
# I will utilize the following tools and datasets to perform my analysis:
# - NYU "2016 New York City Neighborhood Tabulation Areas" GeoJson
# - NYC "DOF: Summary of Neighborhood Sales by Neighborhood Citywide by Borough"
# - CognitiveClass.ai "newyork_data"
#
# The following libraries and APIs will be utilized to analyze and visualize the data:
# Data analysis:
# - Pandas
# - SkLearn
#     - k-means clustering
#     - Statistical Regression
# - Numpy
# Visualization:
# - Folium
# - Matplotlib
# - Seaborn
# Data:
# - Foursquare API
# - NYC OpenData API
#
# Data analysis tools are chosen in order to effectively read and work with Data Frames, perform mathematical analysis and create Machine Learning models. K-means clustering is used in order to group neighborhoods and possibly identify common available investments amongst different areas. It will prove to be useful in observing alternatives after finding a viable investment in another area. Statistical regression is used in order to predict future neighborhood house prices in order to identify trends and give information regarding future value of the investment.
#
# For visualization, Folium is used for geospatial data analysis and the matplotlib and seaborn libraries are used for graphical analysis of numerical and categorical data.
#
# Lastly, the foursquare and NYC OpenData APIs are queried in order to obtain surrouding venues data and geospatial data respectively.

# %% [markdown]
# ### <a id="ETL"> </a>  2.1 Data ETL process

# %% [markdown]
# First, let's analyze the House Sales by Neighborhood for different boroughs in New York. This information comes from the NYC OpenData API, containing information for house sales between 2010 and 2019.

# %%
# Import the required libraries for data gathering, management, visualization and analysis
import requests # Handle API requests
import pandas as pd # Analyze dataframe
from pandas.io.json import json_normalize # Transform json into pandas DataFrame
import numpy 
import matplotlib as plt # Visualization
import seaborn as sns # Visualization

import folium # Geographical data visualization
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# %% [markdown]
# ### 2.1.1 NYC House sales data

# %%
# Get home sales data from NYC OpenDAta API
urlNYC = 'https://data.cityofnewyork.us/resource/5ebm-myj7.json?$limit=50000'
NYC = requests.get(urlNYC).json()
NYC
# Out:
# [{'borough': 'MANHATTAN',
#   'neighborhood': 'ALPHABET CITY',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '593362',
#   'average_sale_price': '593362',
#   'median_sale_price': '593362',
#   'highest_sale_price': '593362.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'ALPHABET CITY',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '1320000',
#   'average_sale_price': '1320000',
#   'median_sale_price': '1320000',
#   'highest_sale_price': '1320000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'ALPHABET CITY',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '900000',
#   'average_sale_price': '900000',
#   'median_sale_price': '900000',
#   'highest_sale_price': '900000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'CHELSEA',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '500000',
#   'average_sale_price': '2875000',
#   'median_sale_price': '2875000',
#   'highest_sale_price': '5250000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'CHELSEA',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '1306213',
#   'average_sale_price': '2603107',
#   'median_sale_price': '2603107',
#   'highest_sale_price': '3900000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'CHELSEA',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '6400000',
#   'average_sale_price': '6400000',
#   'median_sale_price': '6400000',
#   'highest_sale_price': '6400000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'CLINTON',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '3850000',
#   'average_sale_price': '3850000',
#   'median_sale_price': '3850000',
#   'highest_sale_price': '3850000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'EAST VILLAGE',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '3100000',
#   'average_sale_price': '5800000',
#   'median_sale_price': '5800000',
#   'highest_sale_price': '8500000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'EAST VILLAGE',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '477500',
#   'average_sale_price': '2738750',
#   'median_sale_price': '2738750',
#   'highest_sale_price': '5000000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'EAST VILLAGE',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '3290000',
#   'average_sale_price': '3290000',
#   'median_sale_price': '3290000',
#   'highest_sale_price': '3290000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'GRAMERCY',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '2700000',
#   'average_sale_price': '6325000',
#   'median_sale_price': '6325000',
#   'highest_sale_price': '9950000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'GREENWICH VILLAGE-CENTRAL',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '4',
#   'lowest_sale_price': '5100000',
#   'average_sale_price': '13112500',
#   'median_sale_price': '13675000',
#   'highest_sale_price': '20000000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'GREENWICH VILLAGE-WEST',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '11',
#   'lowest_sale_price': '4125000',
#   'average_sale_price': '7160455',
#   'median_sale_price': '6280000',
#   'highest_sale_price': '13580000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'GREENWICH VILLAGE-WEST',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '5',
#   'lowest_sale_price': '2725000',
#   'average_sale_price': '5850000',
#   'median_sale_price': '3400000',
#   'highest_sale_price': '12750000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'GREENWICH VILLAGE-WEST',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '7',
#   'lowest_sale_price': '2475000',
#   'average_sale_price': '4875000',
#   'median_sale_price': '5750000',
#   'highest_sale_price': '6800000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'HARLEM-CENTRAL',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '5',
#   'lowest_sale_price': '200000',
#   'average_sale_price': '1105000',
#   'median_sale_price': '1550000',
#   'highest_sale_price': '1650000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'HARLEM-CENTRAL',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '14',
#   'lowest_sale_price': '800000',
#   'average_sale_price': '1470635',
#   'median_sale_price': '1600000',
#   'highest_sale_price': '2000000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'HARLEM-CENTRAL',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '14',
#   'lowest_sale_price': '595000',
#   'average_sale_price': '989633',
#   'median_sale_price': '961886',
#   'highest_sale_price': '1650000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'HARLEM-EAST',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '950000',
#   'average_sale_price': '950000',
#   'median_sale_price': '950000',
#   'highest_sale_price': '950000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'HARLEM-EAST',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '1340000',
#   'average_sale_price': '1340000',
#   'median_sale_price': '1340000',
#   'highest_sale_price': '1340000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'HARLEM-UPPER',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '450000',
#   'average_sale_price': '1216667',
#   'median_sale_price': '1200000',
#   'highest_sale_price': '2000000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'HARLEM-UPPER',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '8',
#   'lowest_sale_price': '425000',
#   'average_sale_price': '906625',
#   'median_sale_price': '866078',
#   'highest_sale_price': '1450000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'HARLEM-UPPER',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '526050',
#   'average_sale_price': '847229',
#   'median_sale_price': '895637',
#   'highest_sale_price': '1120000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'HARLEM-WEST',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '450000',
#   'average_sale_price': '450000',
#   'median_sale_price': '450000',
#   'highest_sale_price': '450000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'INWOOD',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '600000',
#   'average_sale_price': '600000',
#   'median_sale_price': '600000',
#   'highest_sale_price': '600000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'INWOOD',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '235248',
#   'average_sale_price': '335888',
#   'median_sale_price': '335888',
#   'highest_sale_price': '436527.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'KIPS BAY',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '900000',
#   'average_sale_price': '2075000',
#   'median_sale_price': '2075000',
#   'highest_sale_price': '3250000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'LITTLE ITALY',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '11999900',
#   'average_sale_price': '11999900',
#   'median_sale_price': '11999900',
#   'highest_sale_price': '11999900.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'MIDTOWN EAST',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '3000000',
#   'average_sale_price': '3237500',
#   'median_sale_price': '3237500',
#   'highest_sale_price': '3475000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'MIDTOWN EAST',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '5250000',
#   'average_sale_price': '5250000',
#   'median_sale_price': '5250000',
#   'highest_sale_price': '5250000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'MURRAY HILL',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '5',
#   'lowest_sale_price': '3130000',
#   'average_sale_price': '3696000',
#   'median_sale_price': '3850000',
#   'highest_sale_price': '4200000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'MURRAY HILL',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '1634291',
#   'average_sale_price': '2393097',
#   'median_sale_price': '2550000',
#   'highest_sale_price': '2995000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'SOHO',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '4000000',
#   'average_sale_price': '4000000',
#   'median_sale_price': '4000000',
#   'highest_sale_price': '4000000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'SOHO',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '4250000',
#   'average_sale_price': '4250000',
#   'median_sale_price': '4250000',
#   'highest_sale_price': '4250000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'SOUTHBRIDGE',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '1550000',
#   'average_sale_price': '1550000',
#   'median_sale_price': '1550000',
#   'highest_sale_price': '1550000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'TRIBECA',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '24065000',
#   'average_sale_price': '24065000',
#   'median_sale_price': '24065000',
#   'highest_sale_price': '24065000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'UPPER EAST SIDE (59-79)',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '22',
#   'lowest_sale_price': '1715000',
#   'average_sale_price': '8728302',
#   'median_sale_price': '7625000',
#   'highest_sale_price': '20000000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'UPPER EAST SIDE (59-79)',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '10',
#   'lowest_sale_price': '300000',
#   'average_sale_price': '9776000',
#   'median_sale_price': '10300000',
#   'highest_sale_price': '19660000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'UPPER EAST SIDE (79-96)',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '12',
#   'lowest_sale_price': '2850000',
#   'average_sale_price': '8367085',
#   'median_sale_price': '9545000',
#   'highest_sale_price': '18500000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'UPPER EAST SIDE (79-96)',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '7',
#   'lowest_sale_price': '3200000',
#   'average_sale_price': '11780714',
#   'median_sale_price': '4140000',
#   'highest_sale_price': '44000000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'UPPER EAST SIDE (79-96)',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '3633333',
#   'average_sale_price': '3633333',
#   'median_sale_price': '3633333',
#   'highest_sale_price': '3633333.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'UPPER WEST SIDE (59-79)',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '5',
#   'lowest_sale_price': '6200000',
#   'average_sale_price': '11918062',
#   'median_sale_price': '7650000',
#   'highest_sale_price': '19390312.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'UPPER WEST SIDE (59-79)',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '4',
#   'lowest_sale_price': '3855000',
#   'average_sale_price': '5815394',
#   'median_sale_price': '5303288',
#   'highest_sale_price': '8800000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'UPPER WEST SIDE (59-79)',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '6000000',
#   'average_sale_price': '6000000',
#   'median_sale_price': '6000000',
#   'highest_sale_price': '6000000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'UPPER WEST SIDE (79-96)',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '4',
#   'lowest_sale_price': '3000000',
#   'average_sale_price': '4456250',
#   'median_sale_price': '4537500',
#   'highest_sale_price': '5750000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'UPPER WEST SIDE (79-96)',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '5',
#   'lowest_sale_price': '3200000',
#   'average_sale_price': '4799000',
#   'median_sale_price': '4500000',
#   'highest_sale_price': '8000000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'UPPER WEST SIDE (79-96)',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '3775000',
#   'average_sale_price': '5315033',
#   'median_sale_price': '5182600',
#   'highest_sale_price': '6987500.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'UPPER WEST SIDE (96-116)',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '4750000',
#   'average_sale_price': '5450000',
#   'median_sale_price': '5450000',
#   'highest_sale_price': '6150000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'UPPER WEST SIDE (96-116)',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '3700000',
#   'average_sale_price': '3700000',
#   'median_sale_price': '3700000',
#   'highest_sale_price': '3700000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'WASHINGTON HEIGHTS LOWER',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '7',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '432528',
#   'median_sale_price': '350000',
#   'highest_sale_price': '1100000.00',
#   'year': '2010'},
#  {'borough': 'MANHATTAN',
#   'neighborhood': 'WASHINGTON HEIGHTS LOWER',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '390000',
#   'average_sale_price': '967643',
#   'median_sale_price': '967643',
#   'highest_sale_price': '1545286.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BATHGATE',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '5',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '264306',
#   'median_sale_price': '287000',
#   'highest_sale_price': '313300.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BATHGATE',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '7',
#   'lowest_sale_price': '155000',
#   'average_sale_price': '378805',
#   'median_sale_price': '320000',
#   'highest_sale_price': '869000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BATHGATE',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '5',
#   'lowest_sale_price': '152100',
#   'average_sale_price': '265223',
#   'median_sale_price': '179000',
#   'highest_sale_price': '565015.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BAYCHESTER',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '71',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '293498',
#   'median_sale_price': '303500',
#   'highest_sale_price': '450000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BAYCHESTER',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '60',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '398600',
#   'median_sale_price': '415000',
#   'highest_sale_price': '631315.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BAYCHESTER',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '18',
#   'lowest_sale_price': '161500',
#   'average_sale_price': '460400',
#   'median_sale_price': '475000',
#   'highest_sale_price': '950000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BEDFORD PARK/NORWOOD',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '8',
#   'lowest_sale_price': '172907',
#   'average_sale_price': '326079',
#   'median_sale_price': '332500',
#   'highest_sale_price': '452489.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BEDFORD PARK/NORWOOD',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '19',
#   'lowest_sale_price': '229164',
#   'average_sale_price': '398958',
#   'median_sale_price': '400000',
#   'highest_sale_price': '587507.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BEDFORD PARK/NORWOOD',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '9',
#   'lowest_sale_price': '295000',
#   'average_sale_price': '444333',
#   'median_sale_price': '418000',
#   'highest_sale_price': '594000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BELMONT',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '220000',
#   'average_sale_price': '220000',
#   'median_sale_price': '220000',
#   'highest_sale_price': '220000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BELMONT',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '13',
#   'lowest_sale_price': '190000',
#   'average_sale_price': '319526',
#   'median_sale_price': '326000',
#   'highest_sale_price': '460000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BELMONT',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '8',
#   'lowest_sale_price': '165728',
#   'average_sale_price': '364801',
#   'median_sale_price': '373000',
#   'highest_sale_price': '586500.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BRONX PARK',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '325000',
#   'average_sale_price': '325000',
#   'median_sale_price': '325000',
#   'highest_sale_price': '325000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BRONXDALE',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '27',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '309399',
#   'median_sale_price': '318000',
#   'highest_sale_price': '475000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BRONXDALE',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '42',
#   'lowest_sale_price': '230000',
#   'average_sale_price': '417560',
#   'median_sale_price': '399450',
#   'highest_sale_price': '620000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'BRONXDALE',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '8',
#   'lowest_sale_price': '295000',
#   'average_sale_price': '512189',
#   'median_sale_price': '517800',
#   'highest_sale_price': '700000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'CASTLE HILL/UNIONPORT',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '17',
#   'lowest_sale_price': '215000',
#   'average_sale_price': '334637',
#   'median_sale_price': '345000',
#   'highest_sale_price': '419321.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'CASTLE HILL/UNIONPORT',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '32',
#   'lowest_sale_price': '200000',
#   'average_sale_price': '397238',
#   'median_sale_price': '411000',
#   'highest_sale_price': '568634.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'CASTLE HILL/UNIONPORT',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '6',
#   'lowest_sale_price': '200000',
#   'average_sale_price': '402465',
#   'median_sale_price': '432396',
#   'highest_sale_price': '525000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'CITY ISLAND',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '18',
#   'lowest_sale_price': '253000',
#   'average_sale_price': '494748',
#   'median_sale_price': '460750',
#   'highest_sale_price': '910000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'CITY ISLAND',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '10',
#   'lowest_sale_price': '200000',
#   'average_sale_price': '426050',
#   'median_sale_price': '416250',
#   'highest_sale_price': '615000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'CITY ISLAND',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '330000',
#   'average_sale_price': '460000',
#   'median_sale_price': '460000',
#   'highest_sale_price': '590000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'COUNTRY CLUB',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '35',
#   'lowest_sale_price': '185000',
#   'average_sale_price': '435412',
#   'median_sale_price': '442900',
#   'highest_sale_price': '940000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'COUNTRY CLUB',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '21',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '476917',
#   'median_sale_price': '495000',
#   'highest_sale_price': '875000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'COUNTRY CLUB',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '585680',
#   'average_sale_price': '600340',
#   'median_sale_price': '600340',
#   'highest_sale_price': '615000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'CROTONA PARK',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '5',
#   'lowest_sale_price': '202800',
#   'average_sale_price': '322000',
#   'median_sale_price': '304200',
#   'highest_sale_price': '430000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'CROTONA PARK',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '4',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '407125',
#   'median_sale_price': '490250',
#   'highest_sale_price': '498000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'EAST TREMONT',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '5',
#   'lowest_sale_price': '151000',
#   'average_sale_price': '289920',
#   'median_sale_price': '315000',
#   'highest_sale_price': '350000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'EAST TREMONT',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '27',
#   'lowest_sale_price': '176000',
#   'average_sale_price': '378001',
#   'median_sale_price': '390000',
#   'highest_sale_price': '617416.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'EAST TREMONT',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '12',
#   'lowest_sale_price': '210000',
#   'average_sale_price': '401985',
#   'median_sale_price': '463712',
#   'highest_sale_price': '583000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'FIELDSTON',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '14',
#   'lowest_sale_price': '200000',
#   'average_sale_price': '1239714',
#   'median_sale_price': '1154500',
#   'highest_sale_price': '4150000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'FORDHAM',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '312700',
#   'average_sale_price': '346900',
#   'median_sale_price': '323000',
#   'highest_sale_price': '405000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'FORDHAM',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '5',
#   'lowest_sale_price': '220500',
#   'average_sale_price': '385849',
#   'median_sale_price': '400000',
#   'highest_sale_price': '508746.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'FORDHAM',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '7',
#   'lowest_sale_price': '175000',
#   'average_sale_price': '318430',
#   'median_sale_price': '251245',
#   'highest_sale_price': '510000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'HIGHBRIDGE/MORRIS HEIGHTS',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '310000',
#   'average_sale_price': '411638',
#   'median_sale_price': '411638',
#   'highest_sale_price': '513276.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'HIGHBRIDGE/MORRIS HEIGHTS',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '22',
#   'lowest_sale_price': '195000',
#   'average_sale_price': '385359',
#   'median_sale_price': '391000',
#   'highest_sale_price': '644948.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'HIGHBRIDGE/MORRIS HEIGHTS',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '9',
#   'lowest_sale_price': '230500',
#   'average_sale_price': '471328',
#   'median_sale_price': '450500',
#   'highest_sale_price': '723599.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'HUNTS POINT',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '7',
#   'lowest_sale_price': '261540',
#   'average_sale_price': '373108',
#   'median_sale_price': '320000',
#   'highest_sale_price': '575000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'HUNTS POINT',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '5',
#   'lowest_sale_price': '300000',
#   'average_sale_price': '401800',
#   'median_sale_price': '420000',
#   'highest_sale_price': '480000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'KINGSBRIDGE HTS/UNIV HTS',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '4',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '304150',
#   'median_sale_price': '325800',
#   'highest_sale_price': '415000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'KINGSBRIDGE HTS/UNIV HTS',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '13',
#   'lowest_sale_price': '167000',
#   'average_sale_price': '433768',
#   'median_sale_price': '370000',
#   'highest_sale_price': '1200000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'KINGSBRIDGE HTS/UNIV HTS',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '599000',
#   'average_sale_price': '629500',
#   'median_sale_price': '629500',
#   'highest_sale_price': '660000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'KINGSBRIDGE/JEROME PARK',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '12',
#   'lowest_sale_price': '300000',
#   'average_sale_price': '417806',
#   'median_sale_price': '430000',
#   'highest_sale_price': '540000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'KINGSBRIDGE/JEROME PARK',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '9',
#   'lowest_sale_price': '405000',
#   'average_sale_price': '511714',
#   'median_sale_price': '515000',
#   'highest_sale_price': '595000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'KINGSBRIDGE/JEROME PARK',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '170000',
#   'average_sale_price': '439797',
#   'median_sale_price': '520000',
#   'highest_sale_price': '629391.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MELROSE/CONCOURSE',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '350000',
#   'average_sale_price': '350000',
#   'median_sale_price': '350000',
#   'highest_sale_price': '350000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MELROSE/CONCOURSE',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '14',
#   'lowest_sale_price': '210000',
#   'average_sale_price': '388256',
#   'median_sale_price': '432500',
#   'highest_sale_price': '480000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MELROSE/CONCOURSE',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '18',
#   'lowest_sale_price': '170000',
#   'average_sale_price': '443782',
#   'median_sale_price': '450500',
#   'highest_sale_price': '950000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MORRIS PARK/VAN NEST',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '32',
#   'lowest_sale_price': '165000',
#   'average_sale_price': '398120',
#   'median_sale_price': '389250',
#   'highest_sale_price': '630000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MORRIS PARK/VAN NEST',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '41',
#   'lowest_sale_price': '225000',
#   'average_sale_price': '394260',
#   'median_sale_price': '400000',
#   'highest_sale_price': '555000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MORRIS PARK/VAN NEST',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '9',
#   'lowest_sale_price': '246100',
#   'average_sale_price': '474456',
#   'median_sale_price': '525000',
#   'highest_sale_price': '570000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MORRISANIA/LONGWOOD',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '12',
#   'lowest_sale_price': '185000',
#   'average_sale_price': '286154',
#   'median_sale_price': '302500',
#   'highest_sale_price': '345000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MORRISANIA/LONGWOOD',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '32',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '338612',
#   'median_sale_price': '360000',
#   'highest_sale_price': '516221.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MORRISANIA/LONGWOOD',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '36',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '399398',
#   'median_sale_price': '390897',
#   'highest_sale_price': '999990.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MOTT HAVEN/PORT MORRIS',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '8',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '245331',
#   'median_sale_price': '213825',
#   'highest_sale_price': '410000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MOTT HAVEN/PORT MORRIS',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '8',
#   'lowest_sale_price': '180000',
#   'average_sale_price': '318313',
#   'median_sale_price': '332500',
#   'highest_sale_price': '415000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MOTT HAVEN/PORT MORRIS',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '155000',
#   'average_sale_price': '326258',
#   'median_sale_price': '373775',
#   'highest_sale_price': '450000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MOUNT HOPE/MOUNT EDEN',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '240000',
#   'average_sale_price': '240000',
#   'median_sale_price': '240000',
#   'highest_sale_price': '240000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MOUNT HOPE/MOUNT EDEN',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '300000',
#   'average_sale_price': '335700',
#   'median_sale_price': '335700',
#   'highest_sale_price': '371400.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'MOUNT HOPE/MOUNT EDEN',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '370584',
#   'average_sale_price': '514492',
#   'median_sale_price': '459224',
#   'highest_sale_price': '713667.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'PARKCHESTER',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '5',
#   'lowest_sale_price': '160000',
#   'average_sale_price': '324160',
#   'median_sale_price': '333000',
#   'highest_sale_price': '450000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'PARKCHESTER',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '23',
#   'lowest_sale_price': '160000',
#   'average_sale_price': '402271',
#   'median_sale_price': '425000',
#   'highest_sale_price': '610448.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'PARKCHESTER',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '10',
#   'lowest_sale_price': '270000',
#   'average_sale_price': '484987',
#   'median_sale_price': '495000',
#   'highest_sale_price': '570000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'PELHAM GARDENS',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '15',
#   'lowest_sale_price': '257556',
#   'average_sale_price': '438957',
#   'median_sale_price': '420000',
#   'highest_sale_price': '660000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'PELHAM GARDENS',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '6',
#   'lowest_sale_price': '390000',
#   'average_sale_price': '510333',
#   'median_sale_price': '460500',
#   'highest_sale_price': '685000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'PELHAM GARDENS',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '450000',
#   'average_sale_price': '450000',
#   'median_sale_price': '450000',
#   'highest_sale_price': '450000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'PELHAM PARKWAY NORTH',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '24',
#   'lowest_sale_price': '178745',
#   'average_sale_price': '386218',
#   'median_sale_price': '402500',
#   'highest_sale_price': '661000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'PELHAM PARKWAY NORTH',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '23',
#   'lowest_sale_price': '230000',
#   'average_sale_price': '459736',
#   'median_sale_price': '455000',
#   'highest_sale_price': '640000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'PELHAM PARKWAY NORTH',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '4',
#   'lowest_sale_price': '220000',
#   'average_sale_price': '400813',
#   'median_sale_price': '441625',
#   'highest_sale_price': '500000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'PELHAM PARKWAY SOUTH',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '12',
#   'lowest_sale_price': '325000',
#   'average_sale_price': '446333',
#   'median_sale_price': '385500',
#   'highest_sale_price': '730000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'PELHAM PARKWAY SOUTH',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '7',
#   'lowest_sale_price': '235248',
#   'average_sale_price': '415890',
#   'median_sale_price': '355000',
#   'highest_sale_price': '695000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'PELHAM PARKWAY SOUTH',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '240000',
#   'average_sale_price': '440000',
#   'median_sale_price': '440000',
#   'highest_sale_price': '640000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'RIVERDALE',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '36',
#   'lowest_sale_price': '155000',
#   'average_sale_price': '876418',
#   'median_sale_price': '645000',
#   'highest_sale_price': '3040000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'RIVERDALE',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '7',
#   'lowest_sale_price': '599000',
#   'average_sale_price': '634143',
#   'median_sale_price': '635000',
#   'highest_sale_price': '690000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'RIVERDALE',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '5',
#   'lowest_sale_price': '350000',
#   'average_sale_price': '701000',
#   'median_sale_price': '710000',
#   'highest_sale_price': '975000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'SCHUYLERVILLE/PELHAM BAY',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '33',
#   'lowest_sale_price': '180000',
#   'average_sale_price': '383077',
#   'median_sale_price': '370000',
#   'highest_sale_price': '730000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'SCHUYLERVILLE/PELHAM BAY',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '43',
#   'lowest_sale_price': '202000',
#   'average_sale_price': '457633',
#   'median_sale_price': '439000',
#   'highest_sale_price': '692410.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'SCHUYLERVILLE/PELHAM BAY',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '7',
#   'lowest_sale_price': '370000',
#   'average_sale_price': '531888',
#   'median_sale_price': '550000',
#   'highest_sale_price': '669500.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'SOUNDVIEW',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '15',
#   'lowest_sale_price': '151086',
#   'average_sale_price': '270317',
#   'median_sale_price': '280000',
#   'highest_sale_price': '430000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'SOUNDVIEW',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '45',
#   'lowest_sale_price': '177000',
#   'average_sale_price': '391816',
#   'median_sale_price': '410000',
#   'highest_sale_price': '623823.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'SOUNDVIEW',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '32',
#   'lowest_sale_price': '250000',
#   'average_sale_price': '433954',
#   'median_sale_price': '445600',
#   'highest_sale_price': '630000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'THROGS NECK',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '50',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '375518',
#   'median_sale_price': '375000',
#   'highest_sale_price': '890000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'THROGS NECK',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '55',
#   'lowest_sale_price': '170000',
#   'average_sale_price': '433088',
#   'median_sale_price': '431750',
#   'highest_sale_price': '705000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'THROGS NECK',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '12',
#   'lowest_sale_price': '250000',
#   'average_sale_price': '498413',
#   'median_sale_price': '545000',
#   'highest_sale_price': '655000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'WAKEFIELD',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '41',
#   'lowest_sale_price': '158000',
#   'average_sale_price': '316531',
#   'median_sale_price': '335000',
#   'highest_sale_price': '505056.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'WAKEFIELD',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '40',
#   'lowest_sale_price': '165000',
#   'average_sale_price': '369935',
#   'median_sale_price': '361975',
#   'highest_sale_price': '576600.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'WAKEFIELD',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '7',
#   'lowest_sale_price': '200000',
#   'average_sale_price': '373190',
#   'median_sale_price': '380000',
#   'highest_sale_price': '509000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'WESTCHESTER',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '13',
#   'lowest_sale_price': '170000',
#   'average_sale_price': '309235',
#   'median_sale_price': '300000',
#   'highest_sale_price': '530000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'WESTCHESTER',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '27',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '365574',
#   'median_sale_price': '380000',
#   'highest_sale_price': '534800.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'WESTCHESTER',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '10',
#   'lowest_sale_price': '315000',
#   'average_sale_price': '552603',
#   'median_sale_price': '530750',
#   'highest_sale_price': '713889.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'WILLIAMSBRIDGE',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '39',
#   'lowest_sale_price': '155000',
#   'average_sale_price': '315818',
#   'median_sale_price': '334250',
#   'highest_sale_price': '651235.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'WILLIAMSBRIDGE',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '85',
#   'lowest_sale_price': '160000',
#   'average_sale_price': '368507',
#   'median_sale_price': '375000',
#   'highest_sale_price': '555000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'WILLIAMSBRIDGE',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '27',
#   'lowest_sale_price': '237000',
#   'average_sale_price': '495440',
#   'median_sale_price': '484000',
#   'highest_sale_price': '678006.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'WOODLAWN',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '6',
#   'lowest_sale_price': '200000',
#   'average_sale_price': '354567',
#   'median_sale_price': '374500',
#   'highest_sale_price': '460000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'WOODLAWN',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '11',
#   'lowest_sale_price': '250000',
#   'average_sale_price': '463827',
#   'median_sale_price': '477500',
#   'highest_sale_price': '630000.00',
#   'year': '2010'},
#  {'borough': 'BRONX',
#   'neighborhood': 'WOODLAWN',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '300000',
#   'average_sale_price': '471167',
#   'median_sale_price': '550000',
#   'highest_sale_price': '563500.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BATH BEACH',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '17',
#   'lowest_sale_price': '395000',
#   'average_sale_price': '544790',
#   'median_sale_price': '530000',
#   'highest_sale_price': '705000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BATH BEACH',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '58',
#   'lowest_sale_price': '200000',
#   'average_sale_price': '654117',
#   'median_sale_price': '654000',
#   'highest_sale_price': '1250000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BATH BEACH',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '17',
#   'lowest_sale_price': '175000',
#   'average_sale_price': '794660',
#   'median_sale_price': '790000',
#   'highest_sale_price': '1282995.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BAY RIDGE',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '106',
#   'lowest_sale_price': '190000',
#   'average_sale_price': '780849',
#   'median_sale_price': '670000',
#   'highest_sale_price': '4650000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BAY RIDGE',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '113',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '769807',
#   'median_sale_price': '765000',
#   'highest_sale_price': '2100000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BAY RIDGE',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '17',
#   'lowest_sale_price': '180000',
#   'average_sale_price': '670851',
#   'median_sale_price': '747500',
#   'highest_sale_price': '855000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BEDFORD STUYVESANT',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '23',
#   'lowest_sale_price': '159500',
#   'average_sale_price': '314389',
#   'median_sale_price': '327000',
#   'highest_sale_price': '495000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BEDFORD STUYVESANT',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '254',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '405030',
#   'median_sale_price': '369500',
#   'highest_sale_price': '1240000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BEDFORD STUYVESANT',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '126',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '492702',
#   'median_sale_price': '487500',
#   'highest_sale_price': '1275000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BENSONHURST',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '47',
#   'lowest_sale_price': '310000',
#   'average_sale_price': '626840',
#   'median_sale_price': '590000',
#   'highest_sale_price': '1525000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BENSONHURST',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '117',
#   'lowest_sale_price': '175000',
#   'average_sale_price': '668510',
#   'median_sale_price': '680000',
#   'highest_sale_price': '1145000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BENSONHURST',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '39',
#   'lowest_sale_price': '245000',
#   'average_sale_price': '755910',
#   'median_sale_price': '799000',
#   'highest_sale_price': '1150000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BERGEN BEACH',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '34',
#   'lowest_sale_price': '197774',
#   'average_sale_price': '570106',
#   'median_sale_price': '545000',
#   'highest_sale_price': '1285000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BERGEN BEACH',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '30',
#   'lowest_sale_price': '275000',
#   'average_sale_price': '666875',
#   'median_sale_price': '697500',
#   'highest_sale_price': '840000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BERGEN BEACH',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '6',
#   'lowest_sale_price': '310000',
#   'average_sale_price': '591583',
#   'median_sale_price': '659250',
#   'highest_sale_price': '700000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BOERUM HILL',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '8',
#   'lowest_sale_price': '475000',
#   'average_sale_price': '1263918',
#   'median_sale_price': '1087500',
#   'highest_sale_price': '2390000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BOERUM HILL',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '13',
#   'lowest_sale_price': '800000',
#   'average_sale_price': '1241229',
#   'median_sale_price': '1312500',
#   'highest_sale_price': '2200000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BOERUM HILL',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '1100000',
#   'average_sale_price': '1491667',
#   'median_sale_price': '1625000',
#   'highest_sale_price': '1750000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BOROUGH PARK',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '50',
#   'lowest_sale_price': '233333',
#   'average_sale_price': '582215',
#   'median_sale_price': '557500',
#   'highest_sale_price': '1850000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BOROUGH PARK',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '162',
#   'lowest_sale_price': '160000',
#   'average_sale_price': '677339',
#   'median_sale_price': '672500',
#   'highest_sale_price': '2450000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BOROUGH PARK',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '57',
#   'lowest_sale_price': '175000',
#   'average_sale_price': '809075',
#   'median_sale_price': '818000',
#   'highest_sale_price': '1800000.00',
#   'year': '2010'},
#  {'borough': 'BROOKLYN',
#   'neighborhood': 'BRIGHTON BEACH',
# ...
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'FRESH MEADOWS',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '61',
#   'lowest_sale_price': '255763',
#   'average_sale_price': '622772',
#   'median_sale_price': '625000',
#   'highest_sale_price': '1225000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'FRESH MEADOWS',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '9',
#   'lowest_sale_price': '285505',
#   'average_sale_price': '623312',
#   'median_sale_price': '670000',
#   'highest_sale_price': '842500.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'GLEN OAKS',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '25',
#   'lowest_sale_price': '225000',
#   'average_sale_price': '459620',
#   'median_sale_price': '432500',
#   'highest_sale_price': '960000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'GLEN OAKS',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '4',
#   'lowest_sale_price': '300000',
#   'average_sale_price': '442500',
#   'median_sale_price': '465000',
#   'highest_sale_price': '540000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'GLENDALE',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '61',
#   'lowest_sale_price': '170000',
#   'average_sale_price': '410581',
#   'median_sale_price': '410000',
#   'highest_sale_price': '780000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'GLENDALE',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '53',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '467155',
#   'median_sale_price': '480000',
#   'highest_sale_price': '644000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'GLENDALE',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '10',
#   'lowest_sale_price': '470000',
#   'average_sale_price': '776364',
#   'median_sale_price': '820200',
#   'highest_sale_price': '916425.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HAMMELS',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '7',
#   'lowest_sale_price': '180000',
#   'average_sale_price': '289214',
#   'median_sale_price': '294000',
#   'highest_sale_price': '412000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HAMMELS',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '14',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '258956',
#   'median_sale_price': '255426',
#   'highest_sale_price': '500000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HAMMELS',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '250000',
#   'average_sale_price': '375000',
#   'median_sale_price': '375000',
#   'highest_sale_price': '500000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HILLCREST',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '13',
#   'lowest_sale_price': '355000',
#   'average_sale_price': '487490',
#   'median_sale_price': '475000',
#   'highest_sale_price': '773870.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HILLCREST',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '460000',
#   'average_sale_price': '460000',
#   'median_sale_price': '460000',
#   'highest_sale_price': '460000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HOLLIS',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '134',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '316458',
#   'median_sale_price': '321600',
#   'highest_sale_price': '580000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HOLLIS',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '55',
#   'lowest_sale_price': '165000',
#   'average_sale_price': '341636',
#   'median_sale_price': '340000',
#   'highest_sale_price': '600000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HOLLIS',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '11',
#   'lowest_sale_price': '230000',
#   'average_sale_price': '452313',
#   'median_sale_price': '425000',
#   'highest_sale_price': '610423.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HOLLIS HILLS',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '31',
#   'lowest_sale_price': '210000',
#   'average_sale_price': '661274',
#   'median_sale_price': '628000',
#   'highest_sale_price': '1150000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HOLLISWOOD',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '29',
#   'lowest_sale_price': '156700',
#   'average_sale_price': '731123',
#   'median_sale_price': '680000',
#   'highest_sale_price': '1495000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HOLLISWOOD',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '650000',
#   'average_sale_price': '741667',
#   'median_sale_price': '725000',
#   'highest_sale_price': '850000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HOLLISWOOD',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '445000',
#   'average_sale_price': '445000',
#   'median_sale_price': '445000',
#   'highest_sale_price': '445000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HOWARD BEACH',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '76',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '539546',
#   'median_sale_price': '555000',
#   'highest_sale_price': '1100000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HOWARD BEACH',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '28',
#   'lowest_sale_price': '430000',
#   'average_sale_price': '583571',
#   'median_sale_price': '582500',
#   'highest_sale_price': '720000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'HOWARD BEACH',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '396000',
#   'average_sale_price': '528000',
#   'median_sale_price': '550000',
#   'highest_sale_price': '638000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'JACKSON HEIGHTS',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '68',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '473002',
#   'median_sale_price': '478750',
#   'highest_sale_price': '850000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'JACKSON HEIGHTS',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '72',
#   'lowest_sale_price': '250000',
#   'average_sale_price': '573646',
#   'median_sale_price': '555000',
#   'highest_sale_price': '925000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'JACKSON HEIGHTS',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '21',
#   'lowest_sale_price': '200000',
#   'average_sale_price': '646048',
#   'median_sale_price': '665000',
#   'highest_sale_price': '960000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'JAMAICA',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '26',
#   'lowest_sale_price': '225000',
#   'average_sale_price': '350852',
#   'median_sale_price': '327500',
#   'highest_sale_price': '596743.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'JAMAICA',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '39',
#   'lowest_sale_price': '150425',
#   'average_sale_price': '381585',
#   'median_sale_price': '340000',
#   'highest_sale_price': '720000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'JAMAICA',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '18',
#   'lowest_sale_price': '244000',
#   'average_sale_price': '571907',
#   'median_sale_price': '560000',
#   'highest_sale_price': '946972.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'JAMAICA BAY',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '2',
#   'lowest_sale_price': '185000',
#   'average_sale_price': '210000',
#   'median_sale_price': '210000',
#   'highest_sale_price': '235000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'JAMAICA BAY',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '4',
#   'lowest_sale_price': '175000',
#   'average_sale_price': '310000',
#   'median_sale_price': '260000',
#   'highest_sale_price': '545000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'JAMAICA ESTATES',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '54',
#   'lowest_sale_price': '212000',
#   'average_sale_price': '725162',
#   'median_sale_price': '727000',
#   'highest_sale_price': '1217900.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'JAMAICA ESTATES',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '250000',
#   'average_sale_price': '541000',
#   'median_sale_price': '608000',
#   'highest_sale_price': '765000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'JAMAICA ESTATES',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '677000',
#   'average_sale_price': '677000',
#   'median_sale_price': '677000',
#   'highest_sale_price': '677000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'JAMAICA HILLS',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '26',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '436779',
#   'median_sale_price': '465000',
#   'highest_sale_price': '715000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'JAMAICA HILLS',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '20',
#   'lowest_sale_price': '183000',
#   'average_sale_price': '430418',
#   'median_sale_price': '421000',
#   'highest_sale_price': '645000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'KEW GARDENS',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '20',
#   'lowest_sale_price': '160000',
#   'average_sale_price': '664925',
#   'median_sale_price': '745000',
#   'highest_sale_price': '1220000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'KEW GARDENS',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '12',
#   'lowest_sale_price': '290000',
#   'average_sale_price': '460722',
#   'median_sale_price': '462500',
#   'highest_sale_price': '600000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'KEW GARDENS',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '161600',
#   'average_sale_price': '370533',
#   'median_sale_price': '200000',
#   'highest_sale_price': '750000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'LAURELTON',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '103',
#   'lowest_sale_price': '155000',
#   'average_sale_price': '308860',
#   'median_sale_price': '325000',
#   'highest_sale_price': '620000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'LAURELTON',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '44',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '322025',
#   'median_sale_price': '299485',
#   'highest_sale_price': '712775.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'LITTLE NECK',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '51',
#   'lowest_sale_price': '300000',
#   'average_sale_price': '719060',
#   'median_sale_price': '645000',
#   'highest_sale_price': '2300000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'LITTLE NECK',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '8',
#   'lowest_sale_price': '200000',
#   'average_sale_price': '698125',
#   'median_sale_price': '736000',
#   'highest_sale_price': '887000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'LONG ISLAND CITY',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '6',
#   'lowest_sale_price': '275000',
#   'average_sale_price': '454583',
#   'median_sale_price': '386250',
#   'highest_sale_price': '800000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'LONG ISLAND CITY',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '15',
#   'lowest_sale_price': '206021',
#   'average_sale_price': '624768',
#   'median_sale_price': '605000',
#   'highest_sale_price': '1165000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'LONG ISLAND CITY',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '7',
#   'lowest_sale_price': '233333',
#   'average_sale_price': '672000',
#   'median_sale_price': '605000',
#   'highest_sale_price': '999000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'MASPETH',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '66',
#   'lowest_sale_price': '175000',
#   'average_sale_price': '426832',
#   'median_sale_price': '436750',
#   'highest_sale_price': '675000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'MASPETH',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '83',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '470344',
#   'median_sale_price': '479000',
#   'highest_sale_price': '900000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'MASPETH',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '18',
#   'lowest_sale_price': '400000',
#   'average_sale_price': '608778',
#   'median_sale_price': '595000',
#   'highest_sale_price': '870000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'MIDDLE VILLAGE',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '99',
#   'lowest_sale_price': '150000',
#   'average_sale_price': '473079',
#   'median_sale_price': '485000',
#   'highest_sale_price': '780000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'MIDDLE VILLAGE',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '65',
#   'lowest_sale_price': '162500',
#   'average_sale_price': '533612',
#   'median_sale_price': '520000',
#   'highest_sale_price': '958668.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'MIDDLE VILLAGE',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '20',
#   'lowest_sale_price': '312000',
#   'average_sale_price': '653800',
#   'median_sale_price': '692750',
#   'highest_sale_price': '910000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'NEPONSIT',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '16',
#   'lowest_sale_price': '191967',
#   'average_sale_price': '998685',
#   'median_sale_price': '842500',
#   'highest_sale_price': '2600000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'NEPONSIT',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '1',
#   'lowest_sale_price': '706300',
#   'average_sale_price': '706300',
#   'median_sale_price': '706300',
#   'highest_sale_price': '706300.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'OAKLAND GARDENS',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '55',
#   'lowest_sale_price': '200000',
#   'average_sale_price': '618818',
#   'median_sale_price': '637000',
#   'highest_sale_price': '990000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'OAKLAND GARDENS',
#   'type_of_home': '02 TWO FAMILY HOMES',
#   'number_of_sales': '16',
#   'lowest_sale_price': '722000',
#   'average_sale_price': '1046444',
#   'median_sale_price': '1069163',
#   'highest_sale_price': '1532466.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'OAKLAND GARDENS',
#   'type_of_home': '03 THREE FAMILY HOMES',
#   'number_of_sales': '3',
#   'lowest_sale_price': '770000',
#   'average_sale_price': '808333',
#   'median_sale_price': '810000',
#   'highest_sale_price': '845000.00',
#   'year': '2011'},
#  {'borough': 'QUEENS',
#   'neighborhood': 'OZONE PARK',
#   'type_of_home': '01 ONE FAMILY HOMES',
#   'number_of_sales': '78',
#   'lowest_sale_price': '158000',
#   'average_sale_price': '332743',
#   'median_sale_price': '345000',
#   'highest_sale_price': '500000.00',
#   'year': '2011'},
#  ...]

# %% [markdown]
# ### NYC "DOF: Summary of Neighborhood Sales by Neighborhood Citywide by Borough"
# The following table contains data in 9 categories formatted this way:
#
# ***BOROUGH***
# Department of Finance determines the neighborhood name in the course of valuing properties. The common name of the neighborhood is generally the same as the name Finance designates. However, there may be slight differences in neighborhood boundary lines.
#
# Plain Text
#
# ***NEIGHBORHOOD***
# Department of Finance determines the neighborhood name in the course of valuing properties. The common name of the neighborhood is generally the same as the name Finance designates. However, there may be slight differences in neighborhood boundary lines.
#
# Plain Text
#
# ***TYPE OF HOME***
# Total number of properties for that particular borough and neighborhood
#
# Plain Text
#
# ***NUMBER OF SALES***
# Total number of sales for that particular neighborhood
#
# Number
#
# ***LOWEST SALE PRICE***
# Lowest sales prices for that particular neighborhood
#
# Number
#
# ***AVERAGE SALE PRICE***
# Average sales prices for that particular neighborhood
#
# Number
#
# ***MEDIAN SALE PRICE***
# Median sales prices for that particular neighborhood
#
# Number
#
# ***HIGHEST SALE PRICE***
# Highest sales prices for that particular neighborhood
#
# Number
#
# ***YEAR***
# Year of Summary Report
#
# Plain Text

# %%
# Flatten json into DataFrame
dfNYC = pd.json_normalize(NYC)
dfNYC.head(10)
# Out:
#      borough   neighborhood           type_of_home number_of_sales  \
# 0  MANHATTAN  ALPHABET CITY    01 ONE FAMILY HOMES               1
# 1  MANHATTAN  ALPHABET CITY    02 TWO FAMILY HOMES               1
# 2  MANHATTAN  ALPHABET CITY  03 THREE FAMILY HOMES               1
# 3  MANHATTAN        CHELSEA    01 ONE FAMILY HOMES               2
# 4  MANHATTAN        CHELSEA    02 TWO FAMILY HOMES               2
# 5  MANHATTAN        CHELSEA  03 THREE FAMILY HOMES               1
# 6  MANHATTAN        CLINTON    01 ONE FAMILY HOMES               1
# 7  MANHATTAN   EAST VILLAGE    01 ONE FAMILY HOMES               2
# 8  MANHATTAN   EAST VILLAGE    02 TWO FAMILY HOMES               2
# 9  MANHATTAN   EAST VILLAGE  03 THREE FAMILY HOMES               1
#
#   lowest_sale_price average_sale_price median_sale_price highest_sale_price  \
# 0            593362             593362            593362          593362.00
# 1           1320000            1320000           1320000         1320000.00
# 2            900000             900000            900000          900000.00
# 3            500000            2875000           2875000         5250000.00
# 4           1306213            2603107           2603107         3900000.00
# 5           6400000            6400000           6400000         6400000.00
# 6           3850000            3850000           3850000         3850000.00
# 7           3100000            5800000           5800000         8500000.00
# 8            477500            2738750           2738750         5000000.00
# 9           3290000            3290000           3290000         3290000.00
#
#    year
# 0  2010
# 1  2010
# 2  2010
# 3  2010
# 4  2010
# 5  2010
# 6  2010
# 7  2010
# 8  2010
# 9  2010

# %%
'The NYC House sales data set contains {} rows and {} columns'.format(dfNYC.shape[0],dfNYC.shape[1])
# Out:
# 'The NYC House sales data set contains 5979 rows and 9 columns'

# %% [markdown]
# We can see the data has 5979 rows of data, containing information for lowest, average, median and highest sale price per year in each neighborhood. The data also makes a distinction between the type of home: One family, two family and three family homes.
#
# Let's observe confirm the data types for each column.

# %%
dfNYC.dtypes
# Out:
# borough               object
# neighborhood          object
# type_of_home          object
# number_of_sales       object
# lowest_sale_price     object
# average_sale_price    object
# median_sale_price     object
# highest_sale_price    object
# year                  object
# dtype: object

# %% [markdown]
# Since all the columns contain object variables, let's transform them do more appropriate data types (As described on the data set category introduction).

# %%
numCols = ["number_of_sales","lowest_sale_price","average_sale_price","median_sale_price","highest_sale_price","year"]
dfNYC[numCols]=dfNYC[numCols].apply(pd.to_numeric)
dfNYC.dtypes
# Out:
# borough                object
# neighborhood           object
# type_of_home           object
# number_of_sales         int64
# lowest_sale_price       int64
# average_sale_price      int64
# median_sale_price       int64
# highest_sale_price    float64
# year                    int64
# dtype: object

# %% [markdown]
# Now all the data types are correctly converted.

# %% [markdown]
# ### 2.1.2 Descriptive analysis for NYC House sales data
# Now that we have all the data correctly transformed, let's perform some exploratory descriptive analysis of the data set. Our objective is to find any initial patterns and gain insights on the data distribution, characteristics or trends for each neighborhood, borough or type of home as well as yearly trends.
